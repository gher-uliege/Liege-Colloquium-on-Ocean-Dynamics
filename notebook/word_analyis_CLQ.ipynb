# %% [markdown]
# The goal of this notebook is to analyse the words in the abstract submitted to the 48th Edition of the Colloquium on the Submesoscale.<br>
# First we need to read all the abstracts, then to separate the authors and the abstracts, to finally find the most frequent works.

# %%
# Abstract reading
