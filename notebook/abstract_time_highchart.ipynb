# %%
import netCDF4
import pandas
import re
import time
from time import mktime
from datetime import datetime
import matplotlib.dates as mdates
import matplotlib as mpl
from pandas_highcharts.display import display_charts
from IPython.display import display, display_pretty, Javascript, HTML

# %%
abstractfile = './abstractslist2.txt'

# %%
time4plot = []
time4plot2 = []

# %%
with open(abstractfile, 'r') as f:
    for lines in f:
        match = re.search(r'\d{4}-\d{2}-\d{2}_\d{2}:\d{2}:\d{2}', lines)
        if match:
            abstractdate = match.group()
            timeseconds = time.strptime(abstractdate, "%Y-%m-%d_%H:%M:%S")
            timeseconds2 = time.strptime(abstractdate[:10], "%Y-%m-%d")
            time4plot.append(datetime.fromtimestamp(mktime(timeseconds)))
            time4plot2.append(datetime.fromtimestamp(mktime(timeseconds2)))

# %%
df = pandas.DataFrame(range(0, len(time4plot)), index=time4plot)

# %%
df[:5]
# Out:
#                      0
# 2015-09-23 12:09:47  0
# 2015-10-06 09:10:13  1
# 2015-11-22 17:11:32  2
# 2015-11-23 09:11:22  3
# 2015-11-23 09:11:24  4

# %%
display_charts(df, title='Cumulated number of abstracts', grid='True')
# Out:
# <div id="chart_idDSkVXRvQ"</div>
#     <script type="text/javascript">new Highcharts.Chart({"title":{"text":"Cumulated number of abstracts"},"series":[{"data":[[1443010187000,0],[1444122613000,1],[1448212292000,2],[1448269882000,3],[1448269884000,4],[1449576737000,5],[1449951121000,6],[1450753953000,7],[1450941150000,8],[1450955577000,9],[1451880105000,10],[1451923266000,11],[1452099662000,12],[1452168065000,13],[1452268916000,14],[1452283278000,15],[1452322888000,16],[1452355279000,17],[1452510069000,18],[1452542477000,19],[1452600074000,20],[1452607283000,21],[1452632482000,22],[1452643294000,23],[1452643308000,24],[1452682918000,25],[1452690118000,26],[1452700895000,27],[1452715307000,28],[1452744090000,29],[1452776498000,30],[1452859276000,31],[1453111271000,32],[1453132887000,33],[1453147316000,34],[1453168915000,35],[1453201270000,36],[1453208489000,37],[1453215670000,38],[1453258887000,39],[1453287701000,40],[1453302119000,41],[1453305705000,42],[1453309319000,43],[1453312867000,44],[1453320105000,45],[1453338109000,46],[1453374060000,47],[1453377672000,48],[1453381263000,49],[1453381287000,50],[1453406482000,51],[1453406504000,52],[1453428107000,53],[1453442488000,54],[1453449673000,55],[1453453272000,56],[1453453287000,57],[1453453302000,58],[1453453304000,59],[1453456910000,60],[1453460500000,61],[1453464103000,62],[1453464110000,63],[1453467700